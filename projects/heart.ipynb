# %%
import numpy as np 
import pandas as pd

# %%
from sklearn.datasets import load_iris
iris = load_iris()
x = iris.data
y = iris.target

# %%
feature_names = iris.feature_names
target_names = iris.target_names

print("Feature names: ", feature_names)
print("Target names: ", target_names)
# Out:
# Feature names:  ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target names:  ['setosa' 'versicolor' 'virginica']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=60)

# %%
x_test.shape
# Out:
# (30, 4)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(x)

# %%
print("Accuracy: ", metrics.accuracy_score(y, y_pred))
# Out:
# Accuracy:  0.96

# %%
sample = [[5, 4, 2, 1],
         [6.3, 3.3, 6., 2.5],
         [5.1, 3.5, 1.4, 0.2],
         [2, 4, 1, 8]]


preds = knn.predict(sample)

pred_species = [iris.target_names[p] for p in preds]
for i in range(len(pred_species)):
        print(f"{pred_species[i]} => {sample[i]}")
# Out:
# setosa => [5, 4, 2, 1]
# virginica => [6.3, 3.3, 6.0, 2.5]
# setosa => [5.1, 3.5, 1.4, 0.2]
# versicolor => [2, 4, 1, 8]

# %%
path=r"C:\Users\User\Desktop\IT\AI_python\Pandas\heart.csv"

# %%
import pandas as pd 
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
df = pd.read_csv(path)
df.head(3)
# Out:
#    age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63       1   3       145   233    1        0      150      0      2.3
# 1   37       1   2       130   250    0        1      187      0      3.5
# 2   41       0   1       130   204    0        0      172      0      1.4
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1

# %%
# !pip install scipy==1.11.2
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,4))
sns.set_theme(style="white")
corr = df.corr()
heatmap = sns.heatmap(corr, annot=True)

# %%
x = df.drop('target', axis=1)

# %%
x = x.drop(['age', 'gender', 'cp', 'trestbps', 'chol', 'fbs', 'restecg'], axis=1)

# %%
y = df['target']

# %%
x
# Out:
#      thalach  exang  oldpeak  slope  ca  thal
# 0        150      0      2.3      0   0     1
# 1        187      0      3.5      0   0     2
# 2        172      0      1.4      2   0     2
# 3        178      0      0.8      2   0     2
# 4        163      1      0.6      2   0     2
# ..       ...    ...      ...    ...  ..   ...
# 298      123      1      0.2      1   0     3
# 299      132      0      1.2      1   0     3
# 300      141      0      3.4      1   2     3
# 301      115      1      1.2      1   1     3
# 302      174      0      0.0      1   1     2
#
# [303 rows x 6 columns]

# %%
x[['thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal']]= scaler.fit_transform(x[['thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal']])

# %%
x.head(2)
# Out:
#     thalach     exang   oldpeak     slope        ca      thal
# 0  0.015443 -0.696631  1.087338 -2.274579 -0.714429 -2.148873
# 1  1.633471 -0.696631  2.122573 -2.274579 -0.714429 -0.512922

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state=60)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
Y_pred = knn.predict(x)

# %%
print("Accuracy: ", metrics.accuracy_score(y, Y_pred))
# Out:
# Accuracy:  0.8382838283828383
