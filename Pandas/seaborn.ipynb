# %%
import pandas as pd 
import matplotlib 
import scipy
import seaborn as sns 
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df = sns.load_dataset("car_crashes")
df.head(10)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
# 5   13.6     5.032    3.808          10.744       12.920       835.50
# 6   10.8     4.968    3.888           9.396        8.856      1068.73
# 7   16.2     6.156    4.860          14.094       16.038      1137.87
# 8    5.9     2.006    1.593           5.900        5.900      1273.89
# 9   17.9     3.759    5.191          16.468       16.826      1160.13
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA
# 5      139.91     CO
# 6      167.02     CT
# ...

# %%
from matplotlib import pyplot as plt
x = df.speeding
y = df.alcohol
plt.scatter(x,y)
plt.xlabel("Speeding")
plt.ylabel("Alcohol")
plt.show()

# %%
plt.scatter("speeding", 'alcohol', data=df)
sns.set_style("darkgrid", {"grid.color": '0.5'})
sns.despine()
plt.show()

# %%
df = sns.load_dataset("iris")

# %%
tips = sns.load_dataset('tips')

tips.time.replace('Dinner', 1, inplace=True)
tips.time.replace('Lunch', 2, inplace=True)

plt.scatter(x=tips['total_bill'], y=tips['size'])
plt.xlabel("tip")
plt.ylabel("size")
plt.show()

# %%
tips = sns.load_dataset('tips')

tips.day.replace('Sun', 3, inplace=True)
tips.day.replace('Sat', 2, inplace=True)
tips.day.replace('Thur', 0, inplace=True)
tips.day.replace('Fri', 1, inplace=True)

plt.scatter(x=tips['total_bill'], y=tips['day'])
plt.xlabel("tip")
plt.ylabel("day")
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female      0  Sun  Dinner     2
# 1       10.34  1.66    Male      0  Sun  Dinner     3
# 2       21.01  3.50    Male      0  Sun  Dinner     3
# 3       23.68  3.31    Male      0  Sun  Dinner     2
# 4       24.59  3.61  Female      0  Sun  Dinner     4

# %%
import seaborn as sns
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df = sns.load_dataset("diamonds")
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
import matplotlib
from matplotlib import pyplot as plt
x = df.depth
y = df.table 
plt.scatter(x,y)
plt.xlabel("Depth")
plt.ylabel("Table")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter("depth", 'table', data=df)
sns.set_style("darkgrid", {"grid.color": '0.5'})
sns.despine()
plt.show()
