# %%
data = {
    'olma' : [3, 2, 10, 1],
    'mandarin' : [20, 3,  2, 7]
}

# %%
data
# Out:
# {'olma': [3, 2, 10, 1], 'mandarin': [20, 3, 2, 7]}

# %%
import pandas as pd 

df = pd.DataFrame(data)

# %%
df
# Out:
#    olma  mandarin
# 0     3        20
# 1     2         3
# 2    10         2
# 3     1         7

# %%
df2 = pd.read_csv(r'C:\Users\User\Desktop\IT\AI_python\Pandas\fruit.csv')

# %%
df2
# Out:
#     cherry  strawberry
# 0      1.0        10.0
# 1      2.0         NaN
# 2      3.0        30.0
# 3      4.0        40.0
# 4      NaN        50.0
# 5      6.0        60.0
# 6      7.0        70.0
# 7      8.0         NaN
# 8      NaN        90.0
# 9     10.0       100.0
# 10    11.0       110.0
# 11     NaN       120.0
# 12    13.0       130.0
# 13    14.0         NaN

# %%
df3 = pd.DataFrame(data, index=['Jon', 'Smith', 'Mike', 'MedMax'])

# %%
df3
# Out:
#         olma  mandarin
# Jon        3        20
# Smith      2         3
# Mike      10         2
# MedMax     1         7

# %%
df3.loc["Jon"]
# Out:
# olma         3
# mandarin    20
# Name: Jon, dtype: int64

# %%
m_df = pd.read_csv(r'C:\Users\User\Desktop\IT\AI_python\Pandas\movie.csv', index_col='Title')

# %%
m_df.head(10)
# Out:
#                          Rank                       Genre  \
# Title
# Guardians of the Galaxy     1     Action,Adventure,Sci-Fi
# Prometheus                  2    Adventure,Mystery,Sci-Fi
# Split                       3             Horror,Thriller
# Sing                        4     Animation,Comedy,Family
# Suicide Squad               5    Action,Adventure,Fantasy
# The Great Wall              6    Action,Adventure,Fantasy
# La La Land                  7          Comedy,Drama,Music
# Mindhorn                    8                      Comedy
# The Lost City of Z          9  Action,Adventure,Biography
# Passengers                 10     Adventure,Drama,Romance
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# ...

# %%
m_df.loc['Iron Man 2']
# Out:
# Rank                                                                451
# Genre                                           Action,Adventure,Sci-Fi
# Description           With the world now aware of his identity as Ir...
# Director                                                    Jon Favreau
# Actors                Robert Downey Jr., Mickey Rourke, Gwyneth Palt...
# Year                                                               2010
# Runtime (Minutes)                                                   124
# Rating                                                              7.0
# Votes                                                            556666
# Revenue (Millions)                                                  312
# Metascore                                                          57.0
# Name: Iron Man 2, dtype: object

# %%
m_df.Rank[:2]
# Out:
# Title
# Guardians of the Galaxy    1
# Prometheus                 2
# Name: Rank, dtype: int64

# %%
m_df.rename(columns={
    'Runtime (Minutes)': 'Runtime',
    'Revenue (Millions)': 'Revenue'
}, inplace=True)

m_df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year', 'Runtime',
#        'Rating', 'Votes', 'Revenue', 'Metascore'],
#       dtype='object')

# %%
m_df.head(0)
# Out:
# Empty DataFrame
# Columns: [Rank, Genre, Description, Director, Actors, Year, Runtime, Rating, Votes, Revenue, Metascore]
# Index: []

# %%
#Find non available values 

m_df.isnull().sum()
# Out:
# Rank            0
# Genre           0
# Description     0
# Director        0
# Actors          0
# Year            0
# Runtime         0
# Rating          0
# Votes           0
# Revenue         0
# Metascore      64
# dtype: int64

# %%
#Drop non available values with column

m_df.dropna(axis=1) #inplace = true
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
score = m_df.Metascore
score = round(score.mean(), 0)

# %%
score
# Out:
# 59.0

# %%
m_df.Metascore.fillna(score, inplace=True)

# %%
m_df.Metascore.isnull().sum()
# Out:
# 0
